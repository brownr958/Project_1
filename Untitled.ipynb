# %%
import requests
import json
import pandas as pd
from config import api_key
from pprint import pprint

# %%
# Taking a look at the data base
url = 'https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=exoplanets'
api_key = "&apikey="

# %%
print(url + api_key)
response = requests.get(url + api_key)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=exoplanets&apikey=

# %%
data = pd.read_csv(url)
data
# Out:
#             pl_hostname pl_letter              pl_name    pl_discmethod  \
# 0              HAT-P-19         b           HAT-P-19 b          Transit
# 1              HAT-P-20         b           HAT-P-20 b          Transit
# 2              HAT-P-21         b           HAT-P-21 b          Transit
# 3              HAT-P-22         b           HAT-P-22 b          Transit
# 4              HAT-P-23         b           HAT-P-23 b          Transit
# ...                 ...       ...                  ...              ...
# 4326          MASCARA-4         b          MASCARA-4 b          Transit
# 4327           LHS 1815         b           LHS 1815 b          Transit
# 4328  MOA-2016-BLG-319L         b  MOA-2016-BLG-319L b     Microlensing
# 4329             GJ 317         c             GJ 317 c  Radial Velocity
# 4330           HD 33142         c           HD 33142 c  Radial Velocity
#
#       pl_controvflag  pl_pnum    pl_orbper  pl_orbpererr1  pl_orbpererr2  \
# 0                  0        1     4.008778       0.000006      -0.000006
# 1                  0        1     2.875317       0.000004      -0.000004
# 2                  0        1     4.124480       0.000007      -0.000007
# 3                  0        1     3.212220       0.000009      -0.000009
# 4                  0        1     1.212880       0.000002      -0.000002
# ...              ...      ...          ...            ...            ...
# 4326               0        1     2.824060       0.000030      -0.000030
# 4327               0        1     3.814330       0.000030      -0.000030
# 4328               0        1          NaN            NaN            NaN
# 4329               0        2  6739.323000     143.106000    -143.106000
# 4330               0        2   834.000000      29.000000     -24.000000
#
#       pl_orbperlim  ...  st_masslim  st_massn  st_rad  st_raderr1  st_raderr2  \
# 0              0.0  ...         0.0         2    0.82        0.05       -0.05
# 1              0.0  ...         0.0         5    0.69        0.02       -0.02
# 2              0.0  ...         0.0         3    1.21        0.17       -0.17
# 3              0.0  ...         0.0         6    1.11        0.05       -0.05
# 4              0.0  ...         0.0         5    0.96        0.20       -0.20
# ...            ...  ...         ...       ...     ...         ...         ...
# 4326           0.0  ...         0.0         1    1.92        0.11       -0.11
# 4327           0.0  ...         0.0         2    0.50        0.03       -0.03
# 4328           NaN  ...         0.0         1     NaN         NaN         NaN
# 4329           0.0  ...         0.0         4     NaN         NaN         NaN
# 4330           0.0  ...         0.0         6    4.45         NaN         NaN
#
#       st_radlim  st_radn  pl_nnotes   rowupdate  \
# 0           0.0        3          0  2014-05-14
# 1           0.0        5          0  2014-05-14
# 2           0.0        4          0  2018-04-26
# 3           0.0        6          0  2018-04-26
# 4           0.0        6          0  2018-04-26
# ...         ...      ...        ...         ...
# 4326        0.0        1          0  2020-03-19
# 4327        0.0        2          0  2020-03-19
# 4328        NaN        0          0  2018-11-29
# 4329        0.0        0          0  2020-09-03
# 4330        0.0        5          0  2018-11-29
#
#                                        pl_facility
# 0                                           HATNet
# 1                                           HATNet
# 2                                           HATNet
# 3                                           HATNet
# 4                                           HATNet
# ...                                            ...
# 4326                        Multiple Observatories
# 4327  Transiting Exoplanet Survey Satellite (TESS)
# 4328                                           MOA
# 4329                        W. M. Keck Observatory
# 4330                        W. M. Keck Observatory
#
# [4331 rows x 82 columns]
