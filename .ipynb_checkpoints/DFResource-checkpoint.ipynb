# %%
import requests
import pandas as pd

# %%
# Taking a look at the data base
composite_url = 'https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=compositepars'
api_key = "&apikey="

# %%
# Printing url
print(composite_url + api_key)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=compositepars&apikey=

# %%
# Pulling necessary columns from NASA CSV and cleaning data with null values
nasa_original_df = pd.read_csv(composite_url)
nasa_filter_df = nasa_original_df[["fpl_hostname","fpl_letter","fpl_name","fpl_orbper","fpl_bmasse","fpl_rade","fpl_dens","fpl_eqt","fpl_insol","fst_optmag","fst_teff","fst_mass","fst_rad","fst_age"]]
nasa_clean_df = nasa_filter_df.dropna(how='any')
nasa_clean_df.count()
# Out:
# fpl_hostname    332
# fpl_letter      332
# fpl_name        332
# fpl_orbper      332
# fpl_bmasse      332
# fpl_rade        332
# fpl_dens        332
# fpl_eqt         332
# fpl_insol       332
# fst_optmag      332
# fst_teff        332
# fst_mass        332
# fst_rad         332
# fst_age         332
# dtype: int64

# %%
# Pulling reference data in as a CSV and reading it as a DataFrame
phl = "PHL Habitable Exoplanets.csv"
phl_df = pd.read_csv(phl)
phl_df.head()
# Out:
#                  Name              Type  Mass (ME)  Radius (RE)  Flux (SE)  \
# 0  Teegarden's Star b     M-Warm Terran       1.05          NaN       1.15
# 1           TOI-700 d     M-Warm Terran        NaN         1.14       0.87
# 2             K2-72 e     M-Warm Terran        NaN         1.29       1.11
# 3        TRAPPIST-1 d  M-Warm Subterran       0.41         0.77       1.14
# 4       Kepler-1649 c     M-Warm Terran        NaN         1.06       0.75
#
#    Teq (K)  Period (days)  Distance (ly)   ESI
# 0      264            4.9           12.0  0.95
# 1      246           37.4          101.0  0.93
# 2      261           24.2          217.0  0.90
# 3      263            4.0           41.0  0.90
# 4      237           19.5          301.0  0.90

# %%
# Converting Name column in reference data to a list for for loop check
phl_names = phl_df["Name"].tolist()
print(phl_names)
# Out:
# ["Teegarden's Star b", 'TOI-700 d', 'K2-72 e', 'TRAPPIST-1 d', 'Kepler-1649 c', 'Proxima Cen b', 'GJ 1061 d', 'GJ 1061 c', 'Ross 128 b', 'GJ 273 b', 'TRAPPIST-1 e', 'Kepler-442 b', 'Wolf 1061 c', 'GJ 667 C c', 'GJ 667 C f', 'Kepler-1229 b', 'TRAPPIST-1 f', 'Kepler-62 f', "Teegarden's Star c", 'Kepler-186 f', 'GJ 667 C e', 'tau Cet f', 'TRAPPIST-1 g', 'GJ 682 b', 'Kepler-452 b', 'Kepler-62 e', 'Kepler-1652 b', 'Kepler-1544 b', 'Kepler-296 e', 'Kepler-283 c', 'K2-296 b', 'Kepler-1410 b', 'K2-3 d', 'Kepler-1638 b', 'Kepler-296 f', 'Kepler-440 b', 'Kepler-705 b', 'Kepler-1653 b', 'GJ 832 c', 'Kepler-1606 b', 'Kepler-1090 b', 'Kepler-61 b', 'K2-18 b', 'Kepler-443 b', 'Kepler-1701 b', 'Kepler-22 b', 'LHS 1140 b', 'Kepler-1552 b', 'K2-9 b', 'Kepler-1540 b', 'GJ 180 c', 'Kepler-1632 b', 'Kepler-298 d', 'GJ 163 c', 'HD 40307 g', 'K2-288 B b', 'GJ 3293 d', 'GJ 229 A c', 'Kepler-174 d', 'GJ 357 d']

# %%
# Checking to see how many exoplanets in reference data remain in NASA data
phl_name_list = []
for x in phl_names:
    if not (nasa_clean_df.loc[nasa_clean_df["fpl_name"] == x].empty):
        phl_name_list.append(x)
print(len(phl_name_list))
# Out:
# 22

# %%
# Merging reference data and NASA data
phl_esi_df = phl_df[["Name","ESI"]]
nasa_merge_df = pd.merge(nasa_clean_df, phl_esi_df,left_on="fpl_name",right_on="Name",how="left")

# Pulling necessary columns from merged DF
nasa_clean_merge_df = nasa_merge_df[["fpl_hostname","fpl_name","fpl_orbper","fpl_bmasse","fpl_rade","fpl_dens","fpl_eqt","fpl_insol","fst_optmag","fst_teff","fst_mass","fst_rad","fst_age","ESI"]]
nasa_clean_merge_df.head(5)
# Out:
#   fpl_hostname      fpl_name  fpl_orbper  fpl_bmasse  fpl_rade  fpl_dens  \
# 0      HAT-P-9     HAT-P-9 b    3.922811   238.05467    15.614     0.342
# 1     HAT-P-25    HAT-P-25 b    3.652815   180.84527    12.722     0.483
# 2     HAT-P-29    HAT-P-29 b    5.723190   279.69040    13.115     0.790
# 3     HAT-P-32    HAT-P-32 b    2.150008   216.12440    22.194     0.108
# 4   Kepler-117  Kepler-117 b   18.795923    29.87500     8.059     0.300
#
#    fpl_eqt  fpl_insol  fst_optmag  fst_teff  fst_mass  fst_rad  fst_age  ESI
# 0   1540.0    931.000      12.297    6350.0      1.28     1.34      1.6  NaN
# 1   1182.0    325.000      13.190    5519.0      1.01     0.92      3.2  NaN
# 2   1271.0    433.000      11.900    6087.0      1.45     1.30      2.2  NaN
# 3   1836.0   1841.000      11.289    6001.0      1.13     1.37      2.7  NaN
# 4    984.0    157.541      14.247    6150.0      1.13     1.61      5.3  NaN

# %%
nasaphldf = nasa_clean_merge_df.rename(columns={"fpl_hostname":"Host Name", "fpl_name":"Exoplanet Name","fpl_orbper":"Orbital Period (days)","fpl_bmasse":"Planet Mass [Earth mass]","fpl_rade":"Planet Radius [Earth radii]","fpl_dens":"Planet Density (g/cm**3)","fpl_eqt":"Planet Equilibrium Temperature [K]","fpl_insol":"Insolation Flux [Earth flux]","fst_optmag":"Optical Magnitude [mag]","fst_teff":"Effective Temperature [K]","fst_mass":"Stellar Mass [Solar mass]","fst_rad":"Stellar Radius [Solar radii]","fst_age":"Stellar Age [Gyr]","ESI":"Earth Similarity Index (ESI)"})
nasaphldf.set_index("Exoplanet Name",inplace=True)
nasaphldf.head(50)
# Out:
#                  Host Name  Orbital Period (days)  Planet Mass [Earth mass]  \
# Exoplanet Name
# HAT-P-9 b          HAT-P-9               3.922811                 238.05467
# HAT-P-25 b        HAT-P-25               3.652815                 180.84527
# HAT-P-29 b        HAT-P-29               5.723190                 279.69040
# HAT-P-32 b        HAT-P-32               2.150008                 216.12440
# Kepler-117 b    Kepler-117              18.795923                  29.87500
# Kepler-117 c    Kepler-117              50.790391                 584.78000
# Kepler-120 b    Kepler-120               6.312501                   8.50000
# Kepler-120 c    Kepler-120              12.794585                   2.96000
# Kepler-125 b    Kepler-125               4.164389                   6.21000
# Kepler-186 b    Kepler-186               3.886791                   1.24000
# Kepler-186 c    Kepler-186               7.267302                   2.10000
# Kepler-186 d    Kepler-186              13.342996                   2.54000
# Kepler-205 b    Kepler-205               2.755640                   2.89000
# Kepler-205 c    Kepler-205              20.306546                   3.33000
# Kepler-210 b    Kepler-210               2.453234                   8.96000
# Kepler-210 c    Kepler-210               7.972513                  12.80000
# Kepler-128 b    Kepler-128              15.090000                   0.77000
# Kepler-128 c    Kepler-128              22.804000                   0.90000
# Kepler-130 c    Kepler-130              27.508680                   8.75000
# Kepler-138 c    Kepler-138              13.781300                   1.97000
# Kepler-138 d    Kepler-138              23.088100                   0.64000
# Kepler-144 b    Kepler-144               5.885273                   2.33000
# Kepler-144 c    Kepler-144              10.104665                   2.39000
# Kepler-155 b    Kepler-155               5.931194                   5.02000
# Kepler-155 c    Kepler-155              52.661793                   5.65000
# Kepler-159 b    Kepler-159              10.139623                   6.26000
# Kepler-159 c    Kepler-159              43.595792                  11.50000
# Kepler-167 b    Kepler-167               4.393163                   3.24000
# Kepler-167 c    Kepler-167               7.406114                   3.01000
# HAT-P-36 b        HAT-P-36               1.327347                 587.41341
# HD 7924 b          HD 7924               5.397920                   6.35660
# HD 7924 c          HD 7924              15.299000                   7.86000
# HD 7924 d          HD 7924              24.451000                   6.44000
# Kepler-20 b      Kepler-20               3.696115                   9.70000
# Kepler-20 c      Kepler-20              10.854091                  12.75000
# Kepler-20 d      Kepler-20              77.611300                  10.07000
# Kepler-21 b      Kepler-21               2.785780                   5.08000
# Kepler-22 b      Kepler-22             289.862300                  36.00000
# Kepler-26 b      Kepler-26              12.280000                   5.12000
# Kepler-26 c      Kepler-26              17.255900                   6.20000
# Kepler-26 d      Kepler-26               3.543919                   1.24000
# Kepler-32 d      Kepler-32              22.780200                   7.75000
# Kepler-32 e      Kepler-32               2.896000                   2.86000
# Kepler-32 f      Kepler-32               0.742960                   0.47700
# K2-3 b                K2-3              10.054626                   6.48000
# K2-3 c                K2-3              24.646582                   2.14000
# K2-3 d                K2-3              44.556460                   2.80000
# TrES-2 b            TrES-2               2.470630                 473.56670
# HAT-P-7 b          HAT-P-7               2.204740                 584.80720
# HAT-P-11 b        HAT-P-11               4.887802                  26.69772
#
#                 Planet Radius [Earth radii]  Planet Density (g/cm**3)  \
# Exoplanet Name
# HAT-P-9 b                            15.614                     0.342
# HAT-P-25 b                           12.722                     0.483
# HAT-P-29 b                           13.115                     0.790
# HAT-P-32 b                           22.194                     0.108
# Kepler-117 b                          8.059                     0.300
# Kepler-117 c                         12.341                     1.740
# Kepler-120 b                          2.150                     4.700
# Kepler-120 c                          1.530                     4.540
# Kepler-125 b                          2.370                     2.560
# Kepler-186 b                          1.070                     5.560
# Kepler-186 c                          1.250                     5.910
# Kepler-186 d                          1.400                     5.090
# Kepler-205 b                          1.510                     4.610
# Kepler-205 c                          1.640                     4.150
# Kepler-210 b                          2.940                     1.940
# Kepler-210 c                          3.620                     1.480
# Kepler-128 b                          1.430                     1.460
# Kepler-128 c                          1.340                     2.070
# Kepler-130 c                          2.900                     1.970
# Kepler-138 c                          1.197                     6.200
# Kepler-138 d                          1.212                     2.100
# Kepler-144 b                          1.330                     5.440
# Kepler-144 c                          1.350                     5.340
# Kepler-155 b                          2.090                     3.020
# Kepler-155 c                          2.240                     2.760
# Kepler-159 b                          2.380                     2.550
# Kepler-159 c                          3.410                     1.590
# Kepler-167 b                          1.615                     4.230
# Kepler-167 c                          1.548                     4.460
# HAT-P-36 b                           14.314                     1.175
# HD 7924 b                             2.400                     2.530
# HD 7924 c                             2.720                     2.150
# HD 7924 d                             2.420                     2.500
# Kepler-20 b                           1.868                     8.200
# Kepler-20 c                           3.047                     2.500
# Kepler-20 d                           2.744                     2.700
# Kepler-21 b                           1.639                     6.400
# Kepler-22 b                           2.380                    14.700
# Kepler-26 b                           2.780                     1.260
# Kepler-26 c                           2.720                     1.610
# Kepler-26 d                           1.070                     5.560
# Kepler-32 d                           2.700                     2.160
# Kepler-32 e                           1.500                     4.660
# Kepler-32 f                           0.820                     4.750
# K2-3 b                                1.980                     3.700
# K2-3 c                                1.560                     2.980
# K2-3 d                                1.530                     5.620
# TrES-2 b                             15.244                     0.884
# HAT-P-7 b                            16.926                     0.712
# HAT-P-11 b                            4.360                     1.680
#
#                 Planet Equilibrium Temperature [K]  \
# Exoplanet Name
# HAT-P-9 b                                   1540.0
# HAT-P-25 b                                  1182.0
# HAT-P-29 b                                  1271.0
# HAT-P-32 b                                  1836.0
# Kepler-117 b                                 984.0
# Kepler-117 c                                 704.0
# Kepler-120 b                                 576.0
# Kepler-120 c                                 455.0
# Kepler-125 b                                 594.0
# Kepler-186 b                                 579.0
# Kepler-186 c                                 470.0
# Kepler-186 d                                 384.0
# Kepler-205 b                                 672.0
# Kepler-205 c                                 345.0
# Kepler-210 b                                 734.0
# Kepler-210 c                                 495.0
# Kepler-128 b                                 970.0
# Kepler-128 c                                 845.0
# Kepler-130 c                                 683.0
# Kepler-138 c                                 398.0
# Kepler-138 d                                 335.0
# Kepler-144 b                                1287.0
# Kepler-144 c                                1075.0
# Kepler-155 b                                 614.0
# Kepler-155 c                                 286.0
# Kepler-159 b                                 448.0
# Kepler-159 c                                 275.0
# Kepler-167 b                                 914.0
# Kepler-167 c                                 768.0
# HAT-P-36 b                                  1781.0
# HD 7924 b                                    826.0
# HD 7924 c                                    584.0
# HD 7924 d                                    499.0
# Kepler-20 b                                 1105.0
# Kepler-20 c                                  772.0
# Kepler-20 d                                  401.0
# Kepler-21 b                                 2025.0
# Kepler-22 b                                  262.0
# Kepler-26 b                                  427.0
# Kepler-26 c                                  381.0
# Kepler-26 d                                  646.0
# Kepler-32 d                                  340.0
# Kepler-32 e                                  680.0
# Kepler-32 f                                 1100.0
# K2-3 b                                       504.0
# K2-3 c                                       374.0
# K2-3 d                                       282.0
# TrES-2 b                                    1466.0
# HAT-P-7 b                                   2733.0
# HAT-P-11 b                                   838.0
#
#                 Insolation Flux [Earth flux]  Optical Magnitude [mag]  \
# Exoplanet Name
# HAT-P-9 b                            931.000                   12.297
# HAT-P-25 b                           325.000                   13.190
# HAT-P-29 b                           433.000                   11.900
# HAT-P-32 b                          1841.000                   11.289
# Kepler-117 b                         157.541                   14.247
# Kepler-117 c                          41.863                   14.247
# Kepler-120 b                          42.692                   14.719
# Kepler-120 c                          16.625                   14.719
# Kepler-125 b                          33.184                   14.768
# Kepler-186 b                          37.372                   14.599
# Kepler-186 c                          13.980                   14.599
# Kepler-186 d                           7.204                   14.599
# Kepler-205 b                         102.562                   13.495
# Kepler-205 c                           7.140                   13.495
# Kepler-210 b                         122.139                   13.804
# Kepler-210 c                          25.440                   13.804
# Kepler-128 b                         227.398                   11.289
# Kepler-128 c                         130.979                   11.289
# Kepler-130 c                          46.011                   11.825
# Kepler-138 c                           4.630                   12.472
# Kepler-138 d                           2.320                   12.472
# Kepler-144 b                         426.719                   11.944
# Kepler-144 c                         207.247                   11.944
# Kepler-155 b                          19.000                   14.240
# Kepler-155 c                           1.280                   14.240
# Kepler-159 b                          33.463                   14.888
# Kepler-159 c                           4.791                   14.888
# Kepler-167 b                         115.800                   14.000
# Kepler-167 c                          57.700                   14.000
# HAT-P-36 b                          1821.000                   12.262
# HD 7924 b                            113.700                    7.185
# HD 7924 c                             28.350                    7.185
# HD 7924 d                             15.170                    7.185
# Kepler-20 b                          324.114                   12.510
# Kepler-20 c                           77.023                   12.510
# Kepler-20 d                            5.591                   12.510
# Kepler-21 b                         3021.187                    8.250
# Kepler-22 b                            0.956                   11.644
# Kepler-26 b                            7.600                   15.409
# Kepler-26 c                            4.820                   15.409
# Kepler-26 d                           31.790                   15.409
# Kepler-32 d                            3.631                   16.452
# Kepler-32 e                           56.649                   16.452
# Kepler-32 f                          349.645                   16.452
# K2-3 b                                 5.800                   12.170
# K2-3 c                                 1.770                   12.170
# K2-3 d                                 0.800                   12.170
# TrES-2 b                             903.864                   11.411
# HAT-P-7 b                           4353.408                   10.365
# HAT-P-11 b                           100.770                    9.151
#
#                 Effective Temperature [K]  Stellar Mass [Solar mass]  \
# Exoplanet Name
# HAT-P-9 b                          6350.0                       1.28
# HAT-P-25 b                         5519.0                       1.01
# HAT-P-29 b                         6087.0                       1.45
# HAT-P-32 b                         6001.0                       1.13
# Kepler-117 b                       6150.0                       1.13
# Kepler-117 c                       6150.0                       1.13
# Kepler-120 b                       4096.0                       0.72
# Kepler-120 c                       4096.0                       0.72
# Kepler-125 b                       3810.0                       0.53
# Kepler-186 b                       3755.0                       0.54
# Kepler-186 c                       3755.0                       0.54
# Kepler-186 d                       3755.0                       0.54
# Kepler-205 b                       4321.0                       0.60
# Kepler-205 c                       4321.0                       0.60
# Kepler-210 b                       4559.0                       0.77
# Kepler-210 c                       4559.0                       0.77
# Kepler-128 b                       6136.0                       1.09
# Kepler-128 c                       6136.0                       1.09
# Kepler-130 c                       5884.0                       1.02
# Kepler-138 c                       3841.0                       0.52
# Kepler-138 d                       3841.0                       0.52
# Kepler-144 b                       6075.0                       1.13
# Kepler-144 c                       6075.0                       1.13
# Kepler-155 b                       4508.0                       0.72
# Kepler-155 c                       4508.0                       0.72
# Kepler-159 b                       4625.0                       0.76
# Kepler-159 c                       4625.0                       0.76
# Kepler-167 b                       4890.0                       0.77
# Kepler-167 c                       4890.0                       0.77
# HAT-P-36 b                         5620.0                       1.03
# HD 7924 b                          5131.0                       0.65
# HD 7924 c                          5131.0                       0.65
# HD 7924 d                          5131.0                       0.65
# Kepler-20 b                        5495.0                       0.95
# Kepler-20 c                        5495.0                       0.95
# Kepler-20 d                        5495.0                       0.95
# Kepler-21 b                        6305.0                       1.41
# Kepler-22 b                        5518.0                       0.97
# Kepler-26 b                        3914.0                       0.54
# Kepler-26 c                        3914.0                       0.54
# Kepler-26 d                        3914.0                       0.54
# Kepler-32 d                        3900.0                       0.58
# Kepler-32 e                        3900.0                       0.58
# Kepler-32 f                        3900.0                       0.58
# K2-3 b                             3896.0                       0.60
# K2-3 c                             3896.0                       0.60
# K2-3 d                             3896.0                       0.60
# TrES-2 b                           5850.0                       1.36
# HAT-P-7 b                          6389.0                       1.56
# HAT-P-11 b                         4780.0                       0.81
#
#                 Stellar Radius [Solar radii]  Stellar Age [Gyr]  \
# Exoplanet Name
# HAT-P-9 b                               1.34               1.60
# HAT-P-25 b                              0.92               3.20
# HAT-P-29 b                              1.30               2.20
# HAT-P-32 b                              1.37               2.70
# Kepler-117 b                            1.61               5.30
# Kepler-117 c                            1.61               5.30
# Kepler-120 b                            0.53               3.63
# Kepler-120 c                            0.53               3.63
# Kepler-125 b                            0.51               3.80
# Kepler-186 b                            0.52               4.00
# Kepler-186 c                            0.52               4.00
# Kepler-186 d                            0.52               4.00
# Kepler-205 b                            0.55               3.16
# Kepler-205 c                            0.55               3.16
# Kepler-210 b                            0.65               1.78
# Kepler-210 c                            0.65               1.78
# Kepler-128 b                            1.61               4.07
# Kepler-128 c                            1.61               4.07
# Kepler-130 c                            1.13               5.89
# Kepler-138 c                            0.44               4.68
# Kepler-138 d                            0.44               4.68
# Kepler-144 b                            1.24               3.02
# Kepler-144 c                            1.24               3.02
# Kepler-155 b                            0.62               2.90
# Kepler-155 c                            0.62               2.90
# Kepler-159 b                            0.66               2.51
# Kepler-159 c                            0.66               2.51
# Kepler-167 b                            0.73               3.30
# Kepler-167 c                            0.73               3.30
# HAT-P-36 b                              1.04               6.60
# HD 7924 b                               0.78               0.88
# HD 7924 c                               0.78               0.88
# HD 7924 d                               0.78               0.88
# Kepler-20 b                             0.96               7.60
# Kepler-20 c                             0.96               7.60
# Kepler-20 d                             0.96               7.60
# Kepler-21 b                             1.90               3.03
# Kepler-22 b                             0.98               7.08
# Kepler-26 b                             0.51               2.95
# Kepler-26 c                             0.51               2.95
# Kepler-26 d                             0.51               2.95
# Kepler-32 d                             0.53               2.69
# Kepler-32 e                             0.53               2.69
# Kepler-32 f                             0.53               2.69
# K2-3 b                                  0.56               1.00
# K2-3 c                                  0.56               1.00
# K2-3 d                                  0.56               1.00
# TrES-2 b                                1.12               3.55
# HAT-P-7 b                               2.00               2.07
# HAT-P-11 b                              0.68               6.50
#
#                 Earth Similarity Index (ESI)
# Exoplanet Name
# HAT-P-9 b                                NaN
# HAT-P-25 b                               NaN
# HAT-P-29 b                               NaN
# HAT-P-32 b                               NaN
# Kepler-117 b                             NaN
# Kepler-117 c                             NaN
# Kepler-120 b                             NaN
# Kepler-120 c                             NaN
# Kepler-125 b                             NaN
# Kepler-186 b                             NaN
# Kepler-186 c                             NaN
# Kepler-186 d                             NaN
# Kepler-205 b                             NaN
# Kepler-205 c                             NaN
# Kepler-210 b                             NaN
# Kepler-210 c                             NaN
# Kepler-128 b                             NaN
# Kepler-128 c                             NaN
# Kepler-130 c                             NaN
# Kepler-138 c                             NaN
# Kepler-138 d                             NaN
# Kepler-144 b                             NaN
# Kepler-144 c                             NaN
# Kepler-155 b                             NaN
# Kepler-155 c                             NaN
# Kepler-159 b                             NaN
# Kepler-159 c                             NaN
# Kepler-167 b                             NaN
# Kepler-167 c                             NaN
# HAT-P-36 b                               NaN
# HD 7924 b                                NaN
# HD 7924 c                                NaN
# HD 7924 d                                NaN
# Kepler-20 b                              NaN
# Kepler-20 c                              NaN
# Kepler-20 d                              NaN
# Kepler-21 b                              NaN
# Kepler-22 b                             0.71
# Kepler-26 b                              NaN
# Kepler-26 c                              NaN
# Kepler-26 d                              NaN
# Kepler-32 d                              NaN
# Kepler-32 e                              NaN
# Kepler-32 f                              NaN
# K2-3 b                                   NaN
# K2-3 c                                   NaN
# K2-3 d                                  0.78
# TrES-2 b                                 NaN
# HAT-P-7 b                                NaN
# HAT-P-11 b                               NaN

# %%
# Requesting confirmed planets url for facility list
confirmed_url = 'https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=exoplanets'
facility = pd.read_csv(confirmed_url)
fo_ryan = facility[['pl_name','pl_facility','pl_disc']]
fo_ryan.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-e63ab937afc3> in <module>
#       2 confirmed_url = 'https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=exoplanets'
#       3 facility = pd.read_csv(confirmed_url)
# ----> 4 fo_ryan = facility[['pl_name','pl_facility','pl_disc']]
#       5 fo_ryan.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['pl_disc'] not in index"
