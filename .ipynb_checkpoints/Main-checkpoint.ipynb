# %% [markdown]
# # Planet Discovery and the Possibility of Extraterrestrial Life
#    #### This jupyter notebook serves and the main file for the analysis. Within this file, we will expore NASA's APIs in order to answer the following question: What makes a planet habitiable and how were these planets discovered?
#    #### From this question, and after data exploration, we broke down our analysis into 4 smaller questions which is be analyzed in this notebook:
# ####      1.	How many planets have discovered each year from 2010 to 2020?
# ####      2.	Which facilities have discovered the most planets?
# ####      3.	How many planets fall within the ranges given by the PHL data?
# ####      4.	Which variable (mass, radius, flux, and temperature) has the highest correlation to ESI?
#
#    #### Based on the following analysis, we find that the number of planets discovered only slightly increased from 2010 to 2020, but had major spikes in 2014 and 2016. We also found that Kepler Observatory in India by far, found the most planets. We also found 2 planets that are similar to earth. Finally, we explored which variables impact the Earth Silarity Index (ESI) score the most.

# %%
#Importing Required Dependencies
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from config import g_key
import gmaps
import os
import scipy.stats as stats
from scipy.stats import linregress
from IPython.display import Image

# %%
# Pulling in required data

api_key = "&apikey="

# %%
# Pulling necessary columns from NASA CSV and cleaning data with null values
nasa_original_df = pd.read_csv('Data/composite.csv')
nasa_filter_df = nasa_original_df[["pl_name",'hostname', 'sy_snum']]
nasa_clean_df = nasa_filter_df.dropna(how='any')
nasa_clean_df.head()
# Out:
#       pl_name  hostname  sy_snum
# 0    11 Com b    11 Com        2
# 1    11 UMi b    11 UMi        1
# 2    14 And b    14 And        1
# 3    14 Her b    14 Her        1
# 4  16 Cyg B b  16 Cyg B        3

# %%
# Creating Data Set for Year and Planet Name
nasa_year_df = nasa_original_df[["pl_name","disc_year", "discoverymethod", "sy_dist"]]
nasa_year_df = nasa_year_df.rename(columns={"pl_name": "Planet Name", "disc_year": "Year Discovered", "discoverymethod": "Discovery Method", 
                            "sy_dist": "Distance from Earth (Parsecs)"})
nasa_year_df.head()
# Out:
#   Planet Name  Year Discovered Discovery Method  Distance from Earth (Parsecs)
# 0    11 Com b             2007  Radial Velocity                        93.1846
# 1    11 UMi b             2009  Radial Velocity                       125.3210
# 2    14 And b             2008  Radial Velocity                        75.4392
# 3    14 Her b             2002  Radial Velocity                        17.9323
# 4  16 Cyg B b             1996  Radial Velocity                        21.1397

# %% [markdown]
# # Question 1: How many planets were Discovered each year from 2010 to 2020?
#
#     # Created a table to show the nuimber of planets discovered each year and then visualized it on a line graph. Also grouped again by discovery method to see how many planets were discovered each year by each discovery method. Created a table and graph for this as well. Also created a second visualization to better see the rest of the data.

# %%
# Creating a dataset for number of planets discovered for each year
planet_counts = nasa_year_df.groupby(["Year Discovered"]).count()
planet_counts = planet_counts.drop(columns=["Discovery Method", "Distance from Earth (Parsecs)"]).loc["2010":"2020"]
planet_counts = planet_counts.rename(columns={"Planet Name": "Number of Planets"})
planet_counts
# Out:
#                  Number of Planets
# Year Discovered
# 2010                            97
# 2011                           138
# 2012                           139
# 2013                           125
# 2014                           871
# 2015                           157
# 2016                          1505
# 2017                           153
# 2018                           314
# 2019                           199
# 2020                           227

# %%
# Creating a line chart for number of planets discovered per year
planet_counts["Number of Planets"].plot()
plt.xlim([2010, 2020])
plt.ylabel("Number of Planets")
plt.title("Planets Discovered by Year")
# Out:
# Text(0.5, 1.0, 'Planets Discovered by Year')

# %% [markdown]
# In the first table you’ll notice that there is a large spike both 2014 and 2016 of planet discoveries. The cause of this in 2014 was the invention of a new technique called “verification by multiplicity”. The cause of 2016 spikes can be attributed to another new method called Bayesian Analysis. Of the 1500+ planets discovered that year, 1200 were discovered over the course of one month day.

# %%
# Creating data set for the number of planets by discovery method by year
method = nasa_year_df.groupby(["Year Discovered", "Discovery Method"]).count()
method = method.drop(columns=["Distance from Earth (Parsecs)"])
method = method.loc[2010:2020]
method = method.rename(columns={"Planet Name": "Number of Planets"})
method.head(50)
# Out:
#                                                Number of Planets
# Year Discovered Discovery Method
# 2010            Eclipse Timing Variations                      2
#                 Imaging                                        6
#                 Microlensing                                   2
#                 Radial Velocity                               41
#                 Transit                                       46
# 2011            Eclipse Timing Variations                      5
#                 Imaging                                        2
#                 Microlensing                                   1
#                 Orbital Brightness Modulation                  2
#                 Pulsar Timing                                  1
#                 Radial Velocity                               47
#                 Transit                                       79
#                 Transit Timing Variations                      1
# 2012            Eclipse Timing Variations                      2
#                 Imaging                                        2
#                 Microlensing                                   7
#                 Radial Velocity                               34
#                 Transit                                       93
#                 Transit Timing Variations                      1
# 2013            Astrometry                                     1
#                 Imaging                                        7
#                 Microlensing                                   5
#                 Orbital Brightness Modulation                  1
#                 Radial Velocity                               32
#                 Transit                                       79
# 2014            Imaging                                        2
#                 Microlensing                                   6
#                 Orbital Brightness Modulation                  3
#                 Radial Velocity                               50
#                 Transit                                      798
#                 Transit Timing Variations                     12
# 2015            Eclipse Timing Variations                      1
#                 Imaging                                        5
#                 Microlensing                                   4
#                 Radial Velocity                               47
#                 Transit                                      100
# 2016            Imaging                                        2
#                 Microlensing                                  10
#                 Pulsation Timing Variations                    1
#                 Radial Velocity                               49
#                 Transit                                     1442
#                 Transit Timing Variations                      1
# 2017            Eclipse Timing Variations                      2
#                 Imaging                                        1
#                 Microlensing                                   9
#                 Pulsar Timing                                  2
#                 Radial Velocity                               48
#                 Transit                                       90
#                 Transit Timing Variations                      1
# 2018            Eclipse Timing Variations                      1

# %%
# Creating ine graph of the number of planets by discovery method by year
method.unstack().plot(kind="line")
plt.gcf().set_size_inches(18.5, 10.5)
plt.ylabel("Number of Planets")
plt.title("Planets by Discovery Method by Year")
# Out:
# Text(0.5, 1.0, 'Planets by Discovery Method by Year')

# %% [markdown]
# # Question 2 :This section of the code below will be pulling in the exoplanet data from NASA's API in order to explore the locations of the observatories that discovered the planets.

# %%
# Requesting confirmed exoplanets url for facility list

# Reading the URL as a CSV

# Keeping only the required variables
facility_df = nasa_original_df[['pl_name','disc_facility','sy_dist']]

# %%
# Saving as data frame
df = pd.read_csv("Data/facility_data_locations.csv")
df = df.rename(columns={'pl_facility': 'disc_facility'})
df.head()
# Out:
#                        disc_facility        Lat        Long        Country
# 0                             HATNet  36.601309   36.164228         Turkey
# 1                             Kepler  28.282865   76.950927          India
# 2         Haute-Provence Observatory  43.934786    5.710468         France
# 3             W. M. Keck Observatory  19.826183 -155.474661  United States
# 4  Okayama Astrophysical Observatory  34.576269  133.594117          Japan

# %%
# Merging the two data sets on facility name
merged_facility_df = pd.merge(facility_df,df, on="disc_facility")
# Dropping any Null Values
merged_facility_clean = df = merged_facility_df.dropna(how='any')
merged_facility_clean
# Out:
#               pl_name                           disc_facility      sy_dist  \
# 0            11 Com b                        Xinglong Station    93.184600
# 1         HD 173416 b                        Xinglong Station   132.184000
# 2            11 UMi b  Thueringer Landessternwarte Tautenburg   125.321000
# 3          30 Ari B b  Thueringer Landessternwarte Tautenburg    44.657000
# 4             4 UMa b  Thueringer Landessternwarte Tautenburg    73.460300
# ...               ...                                     ...          ...
# 4366       WASP-176 b                         SuperWASP-North   568.420000
# 4377          WTS-1 b       United Kingdom Infrared Telescope  2346.010000
# 4378          WTS-2 b       United Kingdom Infrared Telescope  1030.768344
# 4379  Wendelstein-1 b                   Haleakala Observatory   305.300000
# 4380  Wendelstein-2 b                   Haleakala Observatory   565.541000
#
#             Lat        Long        Country
# 0     40.414162  117.494419          China
# 1     40.414162  117.494419          China
# 2     50.981792   11.711641        Germany
# 3     50.981792   11.711641        Germany
# 4     50.981792   11.711641        Germany
# ...         ...         ...            ...
# 4366  36.001651  -78.938207  United States
# 4377  19.822641  155.470346        England
# 4378  19.822641  155.470346        England
# 4379  20.708474 -156.256690  United States
# 4380  20.708474 -156.256690  United States
#
# [3533 rows x 6 columns]

# %%
# Grouping by facility name and then the variables of interest in order to save a data frame with just one observation
# for each facility
merged_facility_count = merged_facility_clean.groupby('disc_facility')['pl_name'].count()
merged_facility_lat = merged_facility_clean.groupby('disc_facility')['Lat'].mean()
merged_facility_long = merged_facility_clean.groupby('disc_facility')['Long'].mean()
group_df = pd.DataFrame({"Planet Count": merged_facility_count, "Lat": merged_facility_lat, "Long": merged_facility_long})
group_df
# Out:
#                                               Planet Count        Lat  \
# disc_facility
# Anglo-Australian Telescope                              37  31.675295
# Arecibo Observatory                                      3  18.346504
# Atacama Large Millimeter Array (ALMA)                    1 -23.023168
# Bohyunsan Optical Astronomical Observatory              19  36.164908
# Calar Alto Observatory                                  12  37.220936
# Cerro Tololo Inter-American Observatory                  2 -30.168746
# European Southern Observatory                            2  48.259719
# Fred Lawrence Whipple Observatory                        6  31.675240
# Gemini Observatory                                       9  19.824071
# HATNet                                                  60  36.601309
# Haleakala Observatory                                    2  20.708474
# Haute-Provence Observatory                              51  43.934786
# Hubble Space Telescope                                   4  37.338748
# KMTNet                                                  19 -30.166937
# KOINet                                                   1 -34.580319
# Kepler                                                2393  28.282865
# Kitt Peak National Observatory                           1  31.960090
# La Silla Observatory                                   247 -29.255998
# Large Binocular Telescope Observatory                    2  32.701292
# Las Campanas Observatory                                29 -29.017832
# Leoncito Astronomical Complex                            1 -31.798333
# Lick Observatory                                        33  37.341635
# MEarth Project                                           2  36.542429
# MOA                                                     25  50.033307
# Mauna Kea Observatory                                    1  19.823268
# McDonald Observatory                                    29  30.679989
# Oak Ridge Observatory                                    1  35.837128
# Okayama Astrophysical Observatory                       23  34.576269
# Palomar Observatory                                      2  33.356557
# Paranal Observatory                                     33 -24.627122
# Parkes Observatory                                       2 -32.997804
# Qatar                                                   11  25.236265
# Roque de los Muchachos Observatory                      21  28.757562
# Spitzer Space Telescope                                  3  40.781527
# Subaru Telescope                                         8  19.702875
# SuperWASP                                              113  36.001643
# SuperWASP-North                                          5  36.001651
# Teide Observatory                                        1  28.480735
# Thueringer Landessternwarte Tautenburg                   8  50.981792
# Transiting Exoplanet Survey Satellite (TESS)           126  38.995042
# United Kingdom Infrared Telescope                        2  19.822641
# W. M. Keck Observatory                                 177  19.826183
# Winer Observatory                                        1  31.665895
# Xinglong Station                                         2  40.414162
# Yunnan Astronomical Observatory                          3  25.022361
#
#                                                     Long
# disc_facility
# Anglo-Australian Telescope                   -110.952129
# Arecibo Observatory                           -66.752873
# Atacama Large Millimeter Array (ALMA)         -67.753780
# Bohyunsan Optical Astronomical Observatory    128.977035
# Calar Alto Observatory                         -2.546736
# Cerro Tololo Inter-American Observatory       -70.806311
# European Southern Observatory                  11.670955
# Fred Lawrence Whipple Observatory            -110.951947
# Gemini Observatory                           -155.468840
# HATNet                                         36.164228
# Haleakala Observatory                        -156.256690
# Haute-Provence Observatory                      5.710468
# Hubble Space Telescope                        -92.907154
# KMTNet                                        -70.803993
# KOINet                                         19.351710
# Kepler                                         76.950927
# Kitt Peak National Observatory               -111.599737
# La Silla Observatory                          -70.738035
# Large Binocular Telescope Observatory        -109.889155
# Las Campanas Observatory                      -70.691530
# Leoncito Astronomical Complex                 -69.295664
# Lick Observatory                             -121.642953
# MEarth Project                               -121.895521
# MOA                                            20.220805
# Mauna Kea Observatory                        -155.469234
# McDonald Observatory                         -104.024866
# Oak Ridge Observatory                         -84.623833
# Okayama Astrophysical Observatory             133.594117
# Palomar Observatory                          -116.864946
# Paranal Observatory                           -70.404400
# Parkes Observatory                            148.263064
# Qatar                                          51.129722
# Roque de los Muchachos Observatory            -17.885052
# Spitzer Space Telescope                       -73.973999
# Subaru Telescope                             -155.090295
# SuperWASP                                     -78.938186
# SuperWASP-North                               -78.938207
# Teide Observatory                             -16.308958
# Thueringer Landessternwarte Tautenburg         11.711641
# Transiting Exoplanet Survey Satellite (TESS)  -76.852344
# United Kingdom Infrared Telescope             155.470346
# W. M. Keck Observatory                       -155.474661
# Winer Observatory                            -110.601725
# Xinglong Station                              117.494419
# Yunnan Astronomical Observatory               102.790031

# %%
# Calling API key
gmaps.configure(api_key=g_key)

# Setting location and count
locations = group_df[["Lat", "Long"]]
weights = group_df["Planet Count"]

# Configuring map layout
figure_layout = {
    'width': "100%",
    'height': '400px',
    'padding': '1px',
}

fig = gmaps.figure(layout=figure_layout, center=(21, 4), zoom_level=2.0)
heatmap_layer = gmaps.heatmap_layer(locations, weights=weights, dissipating=False)
fig.add_layer(heatmap_layer)

# Setting heatmap intensity and radius
heatmap_layer.max_intensity = 50
heatmap_layer.point_radius = 4

# Displaying heatmap
fig
# Out:
# Figure(layout=FigureLayout(height='400px', padding='1px', width='100%'))

# %% [markdown]
# ### This heatmap shows the locations of observatories and the size and color of the map represents the number of planets discovered at each observatory.

# %%
# Creating a data frame for the top 5 facilities
top_five_facilities = group_df[group_df['Planet Count'] > 97]
top_five_facilities.reset_index()
# Out:
#                                   disc_facility  Planet Count        Lat  \
# 0                                        Kepler          2393  28.282865
# 1                          La Silla Observatory           247 -29.255998
# 2                                     SuperWASP           113  36.001643
# 3  Transiting Exoplanet Survey Satellite (TESS)           126  38.995042
# 4                        W. M. Keck Observatory           177  19.826183
#
#          Long
# 0   76.950927
# 1  -70.738035
# 2  -78.938186
# 3  -76.852344
# 4 -155.474661

# %%
# Creating a bar chart for the top five facilities
Planet_Count = top_five_facilities['Planet Count']
x_axis = np.arange(len(Planet_Count))

plt.bar(x_axis,Planet_Count, color='r', alpha=0.5, align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Kepler.", "La Silla Observatory.", "SuperWASP.", "TESS.", "W. M. Keck Observatory."], size = 10, rotation=45)

# Labeling the bar chart
plt.xlabel("Facility")
plt.ylabel("Number of Exoplanets Discovered")
plt.title("Top Five Observatories By Number of Exoplanets Discovered")
# Out:
# Text(0.5, 1.0, 'Top Five Observatories By Number of Exoplanets Discovered')

# %% [markdown]
# ### This bar graph shows the top 5 observatories by the number of planets discovered.

# %%
# Creating a data frame for planets found by Country
merged_country_count = merged_facility_clean.groupby('Country')['pl_name'].count()
country_df = pd.DataFrame({"Planet Count": merged_country_count})
country_df
# Out:
#                Planet Count
# Country
# Argentina                 1
# Australia                 2
# Chile                   331
# China                     5
# England                   2
# France                   51
# Germany                  10
# India                  2393
# Japan                    23
# Poland                   25
# Puerto Rico               3
# Qatar                    11
# South Africa              1
# South Korea              19
# Spain                    34
# Turkey                   60
# United States           562

# %%
# Creating a dataframe for top 5 countries
top_five_countries = country_df[country_df['Planet Count'] > 50]
top_five_countries
# Out:
#                Planet Count
# Country
# Chile                   331
# France                   51
# India                  2393
# Turkey                   60
# United States           562

# %%
# Creating a bar chart for the top 5 countries
Planet_Count = top_five_countries['Planet Count']
x_axis = np.arange(len(Planet_Count))

plt.bar(x_axis,Planet_Count, color='r', alpha=0.5, align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Chile", "France", "India", "Turkey", "United States"], size = 12,rotation=45)
plt.xlabel("Country")
plt.ylabel("Number of Exoplanets Discovered")
plt.title("Top Five Countries By Number of Exoplanets Discovered")
# Out:
# Text(0.5, 1.0, 'Top Five Countries By Number of Exoplanets Discovered')

# %% [markdown]
# ### This bar graph shows the top 5 countries in terms of number of planets discovered.

# %% [markdown]
# # Question 3: How many planets fall within the ranges given by the PHL data?
# ### Taking the data provided by the Planetary Habitability Laboratory (PHL), the goal was to find parameters to use to run the other data through in order to properly filter the exoplanets provided by NASA's API. After potentially finding any planets that fit all of the parameters, charts will analyze how the exoplanets are filtered.

# %%
# Taking a look at the data base


# Printing url


# Pulling necessary columns from NASA CSV and cleaning data with null values

nasa_filter_df = nasa_original_df[["hostname","pl_letter","pl_name","pl_orbper","pl_bmasse","pl_rade","pl_dens","pl_eqt","pl_insol","st_lum","st_teff","st_mass","st_rad","st_age"]]
nasa_clean_df = nasa_filter_df.dropna(how='any')
nasa_clean_df.count()
# Out:
# hostname     2512
# pl_letter    2512
# pl_name      2512
# pl_orbper    2512
# pl_bmasse    2512
# pl_rade      2512
# pl_dens      2512
# pl_eqt       2512
# pl_insol     2512
# st_lum       2512
# st_teff      2512
# st_mass      2512
# st_rad       2512
# st_age       2512
# dtype: int64

# %%
# Pulling reference data in as a CSV and reading it as a DataFrame
phl = "Data/PHL Habitable Exoplanets.csv"
phldf = pd.read_csv(phl)
phldf.head()
# Out:
#                  Name              Type  Mass (ME)  Radius (RE)  Flux (SE)  \
# 0  Teegarden's Star b     M-Warm Terran       1.05          NaN       1.15
# 1           TOI-700 d     M-Warm Terran        NaN         1.14       0.87
# 2             K2-72 e     M-Warm Terran        NaN         1.29       1.11
# 3        TRAPPIST-1 d  M-Warm Subterran       0.41         0.77       1.14
# 4       Kepler-1649 c     M-Warm Terran        NaN         1.06       0.75
#
#    Teq (K)  Period (days)  Distance (ly)   ESI
# 0      264            4.9           12.0  0.95
# 1      246           37.4          101.0  0.93
# 2      261           24.2          217.0  0.90
# 3      263            4.0           41.0  0.90
# 4      237           19.5          301.0  0.90

# %%
# Converting Name column in reference data to a list for for loop check
phl_names = phldf["Name"].tolist()
print(phl_names)
# Out:
# ["Teegarden's Star b", 'TOI-700 d', 'K2-72 e', 'TRAPPIST-1 d', 'Kepler-1649 c', 'Proxima Cen b', 'GJ 1061 d', 'GJ 1061 c', 'Ross 128 b', 'GJ 273 b', 'TRAPPIST-1 e', 'Kepler-442 b', 'Wolf 1061 c', 'GJ 667 C c', 'GJ 667 C f', 'Kepler-1229 b', 'TRAPPIST-1 f', 'Kepler-62 f', "Teegarden's Star c", 'Kepler-186 f', 'GJ 667 C e', 'tau Cet f', 'TRAPPIST-1 g', 'GJ 682 b', 'Kepler-452 b', 'Kepler-62 e', 'Kepler-1652 b', 'Kepler-1544 b', 'Kepler-296 e', 'Kepler-283 c', 'K2-296 b', 'Kepler-1410 b', 'K2-3 d', 'Kepler-1638 b', 'Kepler-296 f', 'Kepler-440 b', 'Kepler-705 b', 'Kepler-1653 b', 'GJ 832 c', 'Kepler-1606 b', 'Kepler-1090 b', 'Kepler-61 b', 'K2-18 b', 'Kepler-443 b', 'Kepler-1701 b', 'Kepler-22 b', 'LHS 1140 b', 'Kepler-1552 b', 'K2-9 b', 'Kepler-1540 b', 'GJ 180 c', 'Kepler-1632 b', 'Kepler-298 d', 'GJ 163 c', 'HD 40307 g', 'K2-288 B b', 'GJ 3293 d', 'GJ 229 A c', 'Kepler-174 d', 'GJ 357 d']

# %%
# Checking to see how many exoplanets in reference data remain in NASA data
phl_name_list = []
for x in phl_names:
    if not (nasa_clean_df.loc[nasa_clean_df["pl_name"] == x].empty):
        phl_name_list.append(x)
print(len(phl_name_list))
# Out:
# 33

# %%
# Merging reference data and NASA data
phl_esi_df = phldf[["Name","ESI"]]
nasa_merge_df = pd.merge(nasa_clean_df, phl_esi_df,left_on="pl_name",right_on="Name",how="left")

# Pulling necessary columns from merged DF
nasa_clean_merge_df = nasa_merge_df[["hostname","pl_name","pl_orbper","pl_bmasse","pl_rade","pl_dens","pl_eqt","pl_insol","st_lum","st_teff","st_mass","st_rad","st_age","ESI"]]
nasa_clean_merge_df.head(5)
# Out:
#          hostname           pl_name  pl_orbper  pl_bmasse  pl_rade  pl_dens  \
# 0  EPIC 220674823  EPIC 220674823 b   0.571331       7.72    1.820     8.50
# 1  EPIC 220674823  EPIC 220674823 c  13.339079       5.80    2.730     2.00
# 2  EPIC 246851721  EPIC 246851721 b   6.180235     953.49   11.781     3.10
# 3  EPIC 249893012  EPIC 249893012 b   3.595100       8.75    1.950     6.39
# 4  EPIC 249893012  EPIC 249893012 c  15.624000      14.67    3.670     1.62
#
#    pl_eqt  pl_insol  st_lum  st_teff  st_mass  st_rad  st_age  ESI
# 0  2119.0    4293.0  -0.119   5617.0     0.97    0.98    5.00  NaN
# 1   741.0      64.0  -0.119   5617.0     0.97    0.98    5.00  NaN
# 2  1401.0     642.0   0.526   6202.0     1.32    1.59    3.02  NaN
# 3  1616.0    1037.0   0.356   5430.0     1.05    1.71    9.00  NaN
# 4   990.0     160.0   0.356   5430.0     1.05    1.71    9.00  NaN

# %%
nasaphldf = nasa_clean_merge_df.rename(columns={"hostname":"Host Name", "pl_name":"Exoplanet Name","pl_orbper":"Orbital Period (days)","pl_bmasse":"Planet Mass [Earth mass]","pl_rade":"Planet Radius [Earth radii]","pl_dens":"Planet Density (g/cm**3)","pl_eqt":"Planet Equilibrium Temperature [K]","pl_insol":"Insolation Flux [Earth flux]","st_lum":"Optical Magnitude [mag]","st_teff":"Effective Temperature [K]","st_mass":"Stellar Mass [Solar mass]","st_rad":"Stellar Radius [Solar radii]","st_age":"Stellar Age [Gyr]","ESI":"Earth Similarity Index (ESI)"})
nasaphldf
# Out:
#            Host Name    Exoplanet Name  Orbital Period (days)  \
# 0     EPIC 220674823  EPIC 220674823 b               0.571331
# 1     EPIC 220674823  EPIC 220674823 c              13.339079
# 2     EPIC 246851721  EPIC 246851721 b               6.180235
# 3     EPIC 249893012  EPIC 249893012 b               3.595100
# 4     EPIC 249893012  EPIC 249893012 c              15.624000
# ...              ...               ...                    ...
# 2507        Wolf 503        Wolf 503 b               6.001180
# 2508            XO-7            XO-7 b               2.864142
# 2509        HD 39091          pi Men c               6.267900
# 2510         rho CrB         rho CrB b              39.845800
# 2511         rho CrB         rho CrB c             102.540000
#
#       Planet Mass [Earth mass]  Planet Radius [Earth radii]  \
# 0                      7.72000                        1.820
# 1                      5.80000                        2.730
# 2                    953.49000                       11.781
# 3                      8.75000                        1.950
# 4                     14.67000                        3.670
# ...                        ...                          ...
# 2507                   4.78000                        2.030
# 2508                 225.34147                       15.390
# 2509                   4.82000                        2.042
# 2510                 332.10000                       13.800
# 2511                  25.00000                        5.380
#
#       Planet Density (g/cm**3)  Planet Equilibrium Temperature [K]  \
# 0                        8.500                              2119.0
# 1                        2.000                               741.0
# 2                        3.100                              1401.0
# 3                        6.390                              1616.0
# 4                        1.620                               990.0
# ...                        ...                                 ...
# 2507                     3.140                               805.0
# 2508                     0.340                              1743.0
# 2509                     2.970                              1170.0
# 2510                     0.694                               614.0
# 2511                     0.882                               448.0
#
#       Insolation Flux [Earth flux]  Optical Magnitude [mag]  \
# 0                          4293.00                   -0.119
# 1                            64.00                   -0.119
# 2                           642.00                    0.526
# 3                          1037.00                    0.356
# 4                           160.00                    0.356
# ...                            ...                      ...
# 2507                         69.60                   -0.644
# 2508                       1540.00                    0.431
# 2509                        309.00                    0.160
# 2510                         34.70                    0.232
# 2511                          9.85                    0.232
#
#       Effective Temperature [K]  Stellar Mass [Solar mass]  \
# 0                        5617.0                       0.97
# 1                        5617.0                       0.97
# 2                        6202.0                       1.32
# 3                        5430.0                       1.05
# 4                        5430.0                       1.05
# ...                         ...                        ...
# 2507                     4716.0                       0.69
# 2508                     6250.0                       1.41
# 2509                     6037.0                       1.09
# 2510                     5627.0                       0.89
# 2511                     5627.0                       0.89
#
#       Stellar Radius [Solar radii]  Stellar Age [Gyr]  \
# 0                             0.98               5.00
# 1                             0.98               5.00
# 2                             1.59               3.02
# 3                             1.71               9.00
# 4                             1.71               9.00
# ...                            ...                ...
# 2507                          0.69              11.00
# 2508                          1.48               1.18
# 2509                          1.10               2.98
# 2510                          1.36              10.00
# 2511                          1.36              11.04
#
#       Earth Similarity Index (ESI)
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 2507                           NaN
# 2508                           NaN
# 2509                           NaN
# 2510                           NaN
# 2511                           NaN
#
# [2512 rows x 14 columns]

# %%
phldf1= pd.read_csv(phl)

# %%
# Gathering data to be used as proven potential habitable planets by taking 5 major factors and calculating their bounds
phldf2 = phldf1["Mass (ME)"].dropna(how='any')
radiusphl = phldf1["Radius (RE)"]
# Individually cleaning columns to make the most out of the data that is given
massphl = phldf2

# Converting other 3 columns to be used without cleaning since all data is given
fluxphl = phldf1["Flux (SE)"]
teqphl = phldf1["Teq (K)"]
orbitphl = phldf1["Period (days)"]

# Adding all 5 columns to a variable for for loop and saving list with column names
phlstats = [massphl,radiusphl,fluxphl,teqphl,orbitphl]
phlnames = ["Mass (ME)","Radius (RE)","Flux (SE)","Teq (K)","Period (days)"]

# %%
# Calculating the standard deviations for each column to use as guidelines to find potentially habitable planets
# Saving low and high deviations to list to use for for loop later on
index = 0
lowsd = []
highsd = []
for x in phlstats:
    mean = np.mean(x)
    sd = np.std(x)
    print(f"For {phlnames[index]}, roughly 95% of the data is between {round(mean-2*sd,3)} and {round(mean+2*sd,3)}.")
    lowsd.append(mean-2*sd)
    highsd.append(mean+2*sd)
    index += 1
    
print("Planets outside of these deviation limits will not be appended to the potential habitable planet list.")
# Out:
# For Mass (ME), roughly 95% of the data is between -1.395 and 8.812.
# For Radius (RE), roughly 95% of the data is between 0.828 and 2.752.
# For Flux (SE), roughly 95% of the data is between 0.146 and 1.673.
# For Teq (K), roughly 95% of the data is between 184.756 and 300.944.
# For Period (days), roughly 95% of the data is between -138.725 and 337.791.
# Planets outside of these deviation limits will not be appended to the potential habitable planet list.

# %%
# Removing planets that have an ESI because they are already proven to be potentially habitable
rawnasadf = nasaphldf.loc[pd.isnull(nasaphldf['Earth Similarity Index (ESI)'])]
rawnasadf
# Out:
#            Host Name    Exoplanet Name  Orbital Period (days)  \
# 0     EPIC 220674823  EPIC 220674823 b               0.571331
# 1     EPIC 220674823  EPIC 220674823 c              13.339079
# 2     EPIC 246851721  EPIC 246851721 b               6.180235
# 3     EPIC 249893012  EPIC 249893012 b               3.595100
# 4     EPIC 249893012  EPIC 249893012 c              15.624000
# ...              ...               ...                    ...
# 2507        Wolf 503        Wolf 503 b               6.001180
# 2508            XO-7            XO-7 b               2.864142
# 2509        HD 39091          pi Men c               6.267900
# 2510         rho CrB         rho CrB b              39.845800
# 2511         rho CrB         rho CrB c             102.540000
#
#       Planet Mass [Earth mass]  Planet Radius [Earth radii]  \
# 0                      7.72000                        1.820
# 1                      5.80000                        2.730
# 2                    953.49000                       11.781
# 3                      8.75000                        1.950
# 4                     14.67000                        3.670
# ...                        ...                          ...
# 2507                   4.78000                        2.030
# 2508                 225.34147                       15.390
# 2509                   4.82000                        2.042
# 2510                 332.10000                       13.800
# 2511                  25.00000                        5.380
#
#       Planet Density (g/cm**3)  Planet Equilibrium Temperature [K]  \
# 0                        8.500                              2119.0
# 1                        2.000                               741.0
# 2                        3.100                              1401.0
# 3                        6.390                              1616.0
# 4                        1.620                               990.0
# ...                        ...                                 ...
# 2507                     3.140                               805.0
# 2508                     0.340                              1743.0
# 2509                     2.970                              1170.0
# 2510                     0.694                               614.0
# 2511                     0.882                               448.0
#
#       Insolation Flux [Earth flux]  Optical Magnitude [mag]  \
# 0                          4293.00                   -0.119
# 1                            64.00                   -0.119
# 2                           642.00                    0.526
# 3                          1037.00                    0.356
# 4                           160.00                    0.356
# ...                            ...                      ...
# 2507                         69.60                   -0.644
# 2508                       1540.00                    0.431
# 2509                        309.00                    0.160
# 2510                         34.70                    0.232
# 2511                          9.85                    0.232
#
#       Effective Temperature [K]  Stellar Mass [Solar mass]  \
# 0                        5617.0                       0.97
# 1                        5617.0                       0.97
# 2                        6202.0                       1.32
# 3                        5430.0                       1.05
# 4                        5430.0                       1.05
# ...                         ...                        ...
# 2507                     4716.0                       0.69
# 2508                     6250.0                       1.41
# 2509                     6037.0                       1.09
# 2510                     5627.0                       0.89
# 2511                     5627.0                       0.89
#
#       Stellar Radius [Solar radii]  Stellar Age [Gyr]  \
# 0                             0.98               5.00
# 1                             0.98               5.00
# 2                             1.59               3.02
# 3                             1.71               9.00
# 4                             1.71               9.00
# ...                            ...                ...
# 2507                          0.69              11.00
# 2508                          1.48               1.18
# 2509                          1.10               2.98
# 2510                          1.36              10.00
# 2511                          1.36              11.04
#
#       Earth Similarity Index (ESI)
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 2507                           NaN
# 2508                           NaN
# 2509                           NaN
# 2510                           NaN
# 2511                           NaN
#
# [2479 rows x 14 columns]

# %%
# Cleaning dataframe so it has only the data we are using
nasadf = rawnasadf[["Exoplanet Name","Planet Mass [Earth mass]","Planet Radius [Earth radii]","Insolation Flux [Earth flux]","Planet Equilibrium Temperature [K]","Orbital Period (days)"]]
nasadf
# Out:
#         Exoplanet Name  Planet Mass [Earth mass]  Planet Radius [Earth radii]  \
# 0     EPIC 220674823 b                   7.72000                        1.820
# 1     EPIC 220674823 c                   5.80000                        2.730
# 2     EPIC 246851721 b                 953.49000                       11.781
# 3     EPIC 249893012 b                   8.75000                        1.950
# 4     EPIC 249893012 c                  14.67000                        3.670
# ...                ...                       ...                          ...
# 2507        Wolf 503 b                   4.78000                        2.030
# 2508            XO-7 b                 225.34147                       15.390
# 2509          pi Men c                   4.82000                        2.042
# 2510         rho CrB b                 332.10000                       13.800
# 2511         rho CrB c                  25.00000                        5.380
#
#       Insolation Flux [Earth flux]  Planet Equilibrium Temperature [K]  \
# 0                          4293.00                              2119.0
# 1                            64.00                               741.0
# 2                           642.00                              1401.0
# 3                          1037.00                              1616.0
# 4                           160.00                               990.0
# ...                            ...                                 ...
# 2507                         69.60                               805.0
# 2508                       1540.00                              1743.0
# 2509                        309.00                              1170.0
# 2510                         34.70                               614.0
# 2511                          9.85                               448.0
#
#       Orbital Period (days)
# 0                  0.571331
# 1                 13.339079
# 2                  6.180235
# 3                  3.595100
# 4                 15.624000
# ...                     ...
# 2507               6.001180
# 2508               2.864142
# 2509               6.267900
# 2510              39.845800
# 2511             102.540000
#
# [2479 rows x 6 columns]

# %%
# Finding the planets that meet the mass range provided by the standard deviations
massdf = nasadf.loc[(nasadf["Planet Mass [Earth mass]"] <= highsd[0]) & (nasadf["Planet Mass [Earth mass]"] >= lowsd[0])]
massdf.head()
# Out:
#      Exoplanet Name  Planet Mass [Earth mass]  Planet Radius [Earth radii]  \
# 0  EPIC 220674823 b                      7.72                        1.820
# 1  EPIC 220674823 c                      5.80                        2.730
# 3  EPIC 249893012 b                      8.75                        1.950
# 6          G 9-40 b                      4.76                        2.025
# 8          GJ 887 b                      4.20                        1.880
#
#    Insolation Flux [Earth flux]  Planet Equilibrium Temperature [K]  \
# 0                       4293.00                              2119.0
# 1                         64.00                               741.0
# 3                       1037.00                              1616.0
# 6                          7.20                               456.0
# 8                          7.95                               468.0
#
#    Orbital Period (days)
# 0               0.571331
# 1              13.339079
# 3               3.595100
# 6               5.746007
# 8               9.262000

# %%
# Finding the planets that meet the radius range provided by the standard deviations
radiusdf = massdf.loc[(massdf["Planet Radius [Earth radii]"] <= highsd[1]) & (massdf["Planet Radius [Earth radii]"] >= lowsd[1])]
radiusdf.head()
# Out:
#      Exoplanet Name  Planet Mass [Earth mass]  Planet Radius [Earth radii]  \
# 0  EPIC 220674823 b                      7.72                        1.820
# 1  EPIC 220674823 c                      5.80                        2.730
# 3  EPIC 249893012 b                      8.75                        1.950
# 6          G 9-40 b                      4.76                        2.025
# 8          GJ 887 b                      4.20                        1.880
#
#    Insolation Flux [Earth flux]  Planet Equilibrium Temperature [K]  \
# 0                       4293.00                              2119.0
# 1                         64.00                               741.0
# 3                       1037.00                              1616.0
# 6                          7.20                               456.0
# 8                          7.95                               468.0
#
#    Orbital Period (days)
# 0               0.571331
# 1              13.339079
# 3               3.595100
# 6               5.746007
# 8               9.262000

# %%
# Finding the planets that meet the flux range provided by the standard deviations
fluxdf = radiusdf.loc[(radiusdf["Insolation Flux [Earth flux]"] <= highsd[2]) & (radiusdf["Insolation Flux [Earth flux]"] >= lowsd[2])]
fluxdf.head()
# Out:
#     Exoplanet Name  Planet Mass [Earth mass]  Planet Radius [Earth radii]  \
# 231  Kepler-1058 b                      7.85                         2.72
# 628  Kepler-1362 b                      7.27                         2.60
# 749  Kepler-1455 b                      5.31                         2.16
# 825  Kepler-1512 b                      1.76                         1.18
# 858  Kepler-1539 b                      7.75                         2.70
#
#      Insolation Flux [Earth flux]  Planet Equilibrium Temperature [K]  \
# 231                          0.77                               239.0
# 628                          1.01                               248.0
# 749                          1.53                               298.0
# 825                          1.60                               322.0
# 858                          1.57                               301.0
#
#      Orbital Period (days)
# 231             110.965460
# 628             136.205626
# 749              49.276764
# 825              20.359726
# 858             133.303674

# %%
# Finding the planets that meet the temperature range provided by the standard deviations
teqdf = fluxdf.loc[(fluxdf["Planet Equilibrium Temperature [K]"] <= highsd[3]) & (fluxdf["Planet Equilibrium Temperature [K]"] >= lowsd[3])]
teqdf.head()
# Out:
#     Exoplanet Name  Planet Mass [Earth mass]  Planet Radius [Earth radii]  \
# 231  Kepler-1058 b                      7.85                         2.72
# 628  Kepler-1362 b                      7.27                         2.60
# 749  Kepler-1455 b                      5.31                         2.16
# 872  Kepler-1545 b                      7.75                         2.70
# 876  Kepler-1549 b                      7.13                         2.57
#
#      Insolation Flux [Earth flux]  Planet Equilibrium Temperature [K]  \
# 231                          0.77                               239.0
# 628                          1.01                               248.0
# 749                          1.53                               298.0
# 872                          1.41                               274.0
# 876                          1.18                               286.0
#
#      Orbital Period (days)
# 231             110.965460
# 628             136.205626
# 749              49.276764
# 872             163.692349
# 876             214.886545

# %%
# Finding the planets that meet the orbit range provided by the standard deviations (or all conditions)
orbitdf = teqdf.loc[(teqdf["Orbital Period (days)"] <= highsd[4]) & (teqdf["Orbital Period (days)"] >= lowsd[4])]
orbitdf.head()
# Out:
#     Exoplanet Name  Planet Mass [Earth mass]  Planet Radius [Earth radii]  \
# 231  Kepler-1058 b                      7.85                         2.72
# 628  Kepler-1362 b                      7.27                         2.60
# 749  Kepler-1455 b                      5.31                         2.16
# 872  Kepler-1545 b                      7.75                         2.70
# 876  Kepler-1549 b                      7.13                         2.57
#
#      Insolation Flux [Earth flux]  Planet Equilibrium Temperature [K]  \
# 231                          0.77                               239.0
# 628                          1.01                               248.0
# 749                          1.53                               298.0
# 872                          1.41                               274.0
# 876                          1.18                               286.0
#
#      Orbital Period (days)
# 231             110.965460
# 628             136.205626
# 749              49.276764
# 872             163.692349
# 876             214.886545

# %% [markdown]
# ### After running the dataframe through each criteria based on the Planetary Habitability Laboratory (PHL) statistics, five exoplanets remained.

# %%
# Generating for loop to see how many conditions an exoplanet meets and appending it to the proper list
cond0,cond1,cond2,cond3,cond4,cond5 = [],[],[],[],[],[]
for index, row in nasadf.iterrows():
    cond = 0
    if (row["Planet Mass [Earth mass]"] >= lowsd[0]) & (row["Planet Mass [Earth mass]"] <= highsd[0]):
        cond += 1
    if (row["Planet Radius [Earth radii]"] >= lowsd[1]) & (row["Planet Radius [Earth radii]"] <= highsd[1]):
        cond += 1
    if (row["Insolation Flux [Earth flux]"] >= lowsd[2]) & (row["Insolation Flux [Earth flux]"] <= highsd[2]):
        cond += 1
    if (row["Planet Equilibrium Temperature [K]"] >= lowsd[3]) & (row["Planet Equilibrium Temperature [K]"] <= highsd[3]):
        cond += 1
    if (row["Orbital Period (days)"] >= lowsd[4]) & (row["Orbital Period (days)"] <= highsd[4]):
        cond += 1
    if cond == 0:
        cond0.append(row["Exoplanet Name"])
    elif cond == 1:
        cond1.append(row["Exoplanet Name"])
    elif cond == 2:
        cond2.append(row["Exoplanet Name"])
    elif cond == 3:
        cond3.append(row["Exoplanet Name"])
    elif cond == 4:
        cond4.append(row["Exoplanet Name"])
    elif cond == 5:
        cond5.append(row["Exoplanet Name"])
        
totalcond = [len(cond0),len(cond1),len(cond2),len(cond3),len(cond4),len(cond5)]
print(totalcond)
# Out:
# [3, 618, 278, 1557, 14, 9]

# %%
# Making a pie chart to represent the total number of conditions each exoplanet meets
labels = ["Zero","One","Two","Three","Four","Five"]
colors = ["indigo","mediumblue","steelblue","seagreen","mediumspringgreen","lightgreen"]
explode = (0.5,0.1,0.1,0.1,1.5,2)

# Plotting
plt.pie(totalcond,explode=explode,labels=labels,radius=2,colors=colors,autopct="%1.1f%%",shadow=True,wedgeprops={'linewidth':7.5})
# Out:
# ([<matplotlib.patches.Wedge at 0x1e155ccb860>,
#   <matplotlib.patches.Wedge at 0x1e155cdd2e8>,
#   <matplotlib.patches.Wedge at 0x1e155cddcf8>,
#   <matplotlib.patches.Wedge at 0x1e155ce6748>,
#   <matplotlib.patches.Wedge at 0x1e155cf2198>,
#   <matplotlib.patches.Wedge at 0x1e155cf2ba8>],
#  [Text(2.6999804870700634, 0.010264961807203767, 'Zero'),
#   Text(1.6175626231676161, 1.6350813925095904, 'One'),
#   Text(-0.8004771026573185, 2.156208804388236, 'Two'),
#   Text(-1.0224346489447569, -2.0602493510828275, 'Three'),
#   Text(3.696958002267929, -0.15000509813711232, 'Four'),
#   Text(4.199726821578219, -0.04790223498452881, 'Five')],
#  [Text(1.6999877140811508, 0.0064631241008320005, '0.1%'),
#   Text(0.9142745261382178, 0.924176439244551, '24.9%'),
#   Text(-0.45244357976283217, 1.2187267155237853, '11.2%'),
#   Text(-0.577897845055732, -1.1644887636555112, '62.8%'),
#   Text(2.6977801638171375, -0.10946317972167655, '0.6%'),
#   Text(3.199791864059595, -0.03649694094059337, '0.4%')])

# %% [markdown]
# ### In an effort to see how many total criteria each exoplanet fit, the exoplanets were displayed in a pie chart. As you can see, more than half of the exoplanets met three criteria. And more exoplanets met one criteria than those that met two. Additionally, only three exoplanet met no criteria at all.

# %%
# Gathering number of rows for the number of exoplanets that meet each criteria
accuconddf = [
    (nasadf.loc[(nasadf["Planet Mass [Earth mass]"] <= highsd[0]) & (nasadf["Planet Mass [Earth mass]"] >= lowsd[0])]).shape[0],
    (nasadf.loc[(nasadf["Planet Radius [Earth radii]"] <= highsd[1]) & (nasadf["Planet Radius [Earth radii]"] >= lowsd[1])]).shape[0],
    (nasadf.loc[(nasadf["Insolation Flux [Earth flux]"] <= highsd[2]) & (nasadf["Insolation Flux [Earth flux]"] >= lowsd[2])]).shape[0],
    (nasadf.loc[(nasadf["Planet Equilibrium Temperature [K]"] <= highsd[3]) & (nasadf["Planet Equilibrium Temperature [K]"] >= lowsd[3])]).shape[0],
    (nasadf.loc[(nasadf["Orbital Period (days)"] <= highsd[4]) & (nasadf["Orbital Period (days)"] >= lowsd[4])]).shape[0]]

# Plotting
colors2 = ["indigo","mediumblue","steelblue","seagreen","mediumspringgreen"]
xaxis = np.arange(len(accuconddf))
plt.bar(xaxis,accuconddf,color=colors2)
tick_locations = [value for value in xaxis]
plt.xticks(tick_locations,phlnames)
plt.ylabel("Number of Exoplanets")
plt.title("Exoplanets that meet each Criteria")
# Out:
# Text(0.5, 1.0, 'Exoplanets that meet each Criteria')

# %% [markdown]
# ### In order to see how many of the exoplanets were being funnelled by each criteria, the totals for each criteria met were taken and displayed into a bar chart. Almost all of the exoplanets seemed to fall within the range that was given for orbital period. When the exoplanets were filtered through Flux and the equilibrium temperature (Teq), however, not many fell within the range.

# %% [markdown]
# # Question 4: The point of this question is to see if there are particular variables that we think correlate most with the ESI. We chose variables that would seem to have most important roles. Using an ESI index and choosing 4 intiial variables, equilibrium temperature, insolation of the planet, mass in relation to earth, and its radius. Two additional variables were proposed, the age of the star and the brightness.

# %%
#Isolated the columns needed for the graphs
phl_esi_df = phldf[["Name","ESI"]]
graphs = pd.merge(nasa_filter_df, phl_esi_df,left_on="pl_name",right_on="Name",how="left")

#Dropped null values to make sure all data was graphed as best as it could be
graphs2 = graphs[["hostname","pl_name","pl_orbper","pl_bmasse","pl_rade","pl_dens","pl_eqt","pl_insol","st_lum","st_teff","st_mass","st_rad","st_age","ESI"]]
dropped = graphs2.dropna(subset = ['pl_eqt' , 'ESI'])
dropped1 = graphs2.dropna(subset = ['pl_insol' , 'ESI'])
dropped2 = graphs2.dropna(subset = ['pl_bmasse' , 'ESI'])
dropped3 = graphs2.dropna(subset = ['pl_rade' , 'ESI'])
dropped4 = graphs2.dropna(subset = ['st_age' , 'ESI'])

# %%
#Defined plot linear to condense code for each scatter plot to call later.
def plot_linear(x_values, y_values, title, text_coor):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coor,fontsize=15,color="red")
    print(f"r-value:{rvalue**2}")
    plt.show()

# %%
#Scatter plot 1
x_values = dropped1['pl_insol']
y_values = dropped1['ESI']
plt.xlabel('Flux Insolation')
plt.ylabel('Earth Similarity Index')
plt.title('Flux Insolation vs Earth Similiarity Index')
plot_linear(x_values, y_values,'Max Temp',(1, 1))
# Out:
# r-value:0.0008679914450868852

# %% [markdown]
#     This scatter plot is showing that there is not a strong correlation
#     between the insolation of the planet and the ESI
#     It does show that these planets have a simniliar flux but still vary in ESI.

# %%
#Scatter Plot 2
x_values = dropped2['pl_bmasse']
y_values = dropped2['ESI']
plt.scatter(x_values,y_values)
plt.xlabel('Mass of Planet (Earths)')
plt.ylabel('Earth Similarity Index')
plt.title('Mass of Planet(Earths) vs Earth Similiarity Index')
plot_linear(x_values, y_values,'Max Temp',(1, 1))
# Out:
# r-value:0.025966953256867334

# %% [markdown]
#     This scatter plot much like the one above does not show a correlation
#     but it does show that several of these planets do share or are
#     close to the same mass

# %% [markdown]
#     All of the below T Tests show that there is some statistical significance
#     to our data and are the original 4 variables we proposed to be significant
#     to finding an earth like planet. The bottom two do not see, to gave
#     Significance and are two potential variables we proposed.

# %%
#Defined the T Test variables for the sample 
ttest = nasa_filter_df[nasa_filter_df['pl_name'].isin(phl_names)]
ttest_clean = ttest.dropna(subset = ['pl_eqt'])
ttest_mean = ttest_clean['pl_eqt']

#Defined the T test variables for the entire population
ttesto = nasa_filter_df
ttesto_clean = ttesto.dropna(subset = ['pl_eqt'])
ttesto_mean = ttesto_clean['pl_eqt'].mean()
#Ran the T Test
stats.ttest_1samp(ttest_mean, ttesto_mean)
# Out:
# Ttest_1sampResult(statistic=-99.99823556322296, pvalue=1.3173510019619272e-50)

# %%
#T Test 2
ttest1_clean = ttest.dropna(subset = ['pl_insol'])
ttest1_mean = ttest1_clean['pl_insol']

ttesto1_clean = ttesto.dropna(subset = ['pl_insol'])
ttesto1_mean = ttesto1_clean['pl_insol'].mean()

stats.ttest_1samp(ttest1_mean, ttesto1_mean)
# Out:
# Ttest_1sampResult(statistic=-2851.5269090146935, pvalue=9.314977566315516e-125)

# %%
#T Test 3
ttest2_clean = ttest.dropna(subset = ['pl_bmasse'])
ttest2_mean = ttest2_clean['pl_bmasse']

ttesto2_clean = ttesto.dropna(subset = ['pl_insol'])
ttesto2_mean = ttesto2_clean['pl_insol'].mean()

stats.ttest_1samp(ttest2_mean, ttesto2_mean)
# Out:
# Ttest_1sampResult(statistic=-373.9422470951544, pvalue=8.510738064705066e-100)

# %%
#T Test 4
ttest3_clean = ttest.dropna(subset = ['pl_rade'])
ttest3_mean = ttest3_clean['pl_rade']

ttesto3_clean = ttesto.dropna(subset = ['pl_rade'])
ttesto3_mean = ttesto3_clean['pl_rade'].mean()

stats.ttest_1samp(ttest3_mean, ttesto3_mean)
# Out:
# Ttest_1sampResult(statistic=-57.37032427509842, pvalue=8.660857290389607e-53)

# %%
#T Test 5
ttest4_clean = ttest.dropna(subset = ['st_lum'])
ttest4_mean = ttest4_clean['st_lum']
ttesto4_clean = ttesto.dropna(subset = ['st_lum'])
ttesto4_mean = ttesto4_clean['st_lum'].mean()

stats.ttest_1samp(ttest4_mean, ttesto4_mean)
# Out:
# Ttest_1sampResult(statistic=-10.800869071155752, pvalue=1.6532981619201975e-15)

# %%
# T Test 6
ttest5_clean = ttest.dropna(subset = ['st_age'])
ttest5_mean = ttest5_clean['st_age']

ttesto5_clean = ttesto.dropna(subset = ['st_age'])
ttesto5_mean = ttesto5_clean['st_age'].mean()

stats.ttest_1samp(ttest5_mean, ttesto5_mean)
# Out:
# Ttest_1sampResult(statistic=-0.8266873660048021, pvalue=0.41259160020337216)

# %% [markdown]
# # Summary Notes
#       1. Kepler-155c and Kepler 1455 b
#       2. Found the two most popular years for planet discoveries (2014, 2016)
#       3. Kepler Observatory in India has found the most planets
#       4. No statistical Significance was found

# %%
picture2 = 'NASAExoplanets/Kepler1058.png'
Image(filename=picture2)

# %%
picture2 = 'NASAExoplanets/Kepler1455b.png'
Image(filename=picture2)

# %%
picture2 = 'NASAExoplanets/Kepler1362b.png'
Image(filename=picture2)

# %%
picture2 = 'NASAExoplanets/Kepler1545b.png'
Image(filename=picture2)

# %%
picture2 = 'NASAExoplanets/Kepler1549b.png'
Image(filename=picture2)
